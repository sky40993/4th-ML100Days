# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
def mean_absolute_error(y, yp):
    mae = MAE = sum(abs(y - yp)) / len(y)
    return mae

def mean_squared_error(y, yp):
    mse = MSE = sum((y - yp)**2) / len(y)
    return mse

# %%
w = 3
b = 0.5
x_lin = np.linspace(0, 100, 101)
y = (x_lin + np.random.randn(101) * 5) * w + b

plt.plot(x_lin, y, 'b.', label = 'data points')
plt.title("Assume we have data points")
plt.legend(loc = 2)
plt.show()

# %%
y_hat = x_lin * w + b
plt.plot(x_lin, y, 'b.', label = 'data')
plt.plot(x_lin, y_hat, 'r-', label = 'prediction')
plt.title("Assume we have data points (And the prediction)")
plt.legend(loc = 2)
plt.show()

# %%
MSE = mean_squared_error(y, y_hat)
MAE = mean_absolute_error(y, y_hat)
print("The Mean squared error is %.3f" % (MSE))
print("The Mean absolute error is %.3f" % (MAE))
# Out:
# The Mean squared error is 214.550
# The Mean absolute error is 11.578

# %%
#Homework2--Titanic: Machine Learning from Disaster
#1. 你選的這組資料為何重要
    #災害從不間斷，災害可大可小，某些災害會是無法承受之重，如果有模型能夠預測災害發生時個位置的生存機率那麼
    #也許我們可以藉由此預測資料來改進現有制度

#2. 資料從何而來 (tips: 譬如提供者是誰、以什麼方式蒐集)
    #這部分我沒有真的看到有哪個人的名字出現在上面所以我猜是主辦單位Kaggle提供的，他們資料的來源為歷史沈船事件鐵達尼號
    #的資料
#3. 蒐集而來的資料型態為何
    #結構化資料需要檢視欄欄位意義以及名稱 e.g. survival	Survival	0 = No, 1 = Yes
    #pclass	Ticket class	1 = 1st, 2 = 2nd, 3 = 3rd
    #sex	Sex	
    #Age	Age in years	
    #sibsp	# of siblings / spouses aboard the Titanic	
    #parch	# of parents / children aboard the Titanic	
    #ticket	Ticket number	
    #fare	Passenger fare
#4. 這組資料想解決的問題如何評估
    #用單位給的測試組與訓練組來做比對

# %%
#Homework3--Titanic: Machine Learning from Disaster
    #1提升載客效率
    #2歷年來乘客上下車地點及時間的歷史資料
    #3數字(時間)及文字(地點、乘客資訊)
    #4未來營運時藉由其數據訓練預測過後的資訊來比對，其準確度
